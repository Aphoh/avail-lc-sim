# %%
import pandas as pd
import numpy as np
from statsmodels.stats.proportion import proportion_confint
import seaborn as sns
import matplotlib.colors as colors
import matplotlib.pyplot as plt
sns.set_theme()

# %%
df = pd.read_csv("samples.csv")
df.head()
# Out:
#    dims  matrix_size  n_clients  percent_censored  n_samples   prob
# 0     1           16         50               0.0         10  0.982
# 1     2           16         50               0.0         10  0.998
# 2     1           32         50               0.0         10  0.206
# 3     2           32         50               0.0         10  0.228
# 4     1           64         50               0.0         10  0.062

# %%
df["prob_95_conf"] = df.apply(lambda r: proportion_confint(count=500*r['prob'], nobs=500, method="wilson")[0], axis=1)

# %%
df["n_clients"].unique()
# Out:
# array([  50,  100,  150,  200,  250,  300,  350,  400,  450,  500,  550,
#         600,  650,  700,  750,  800,  850,  900,  950, 1000])

# %%
sns.relplot(data=df[df["dims"] == 2], x="n_clients", y="prob_95_conf", hue="percent_censored", col="n_samples", row="matrix_size")

# %%
sns.relplot(data=df[df["dims"] == 1], x="n_clients", y="prob_95_conf", hue="percent_censored", col="n_samples", row="matrix_size")

# %%
import numpy as np
def ex(n, f):
    denom = n + 1 + np.arange(n).astype(float)
    return 2 * n**3 * (np.ones(n) / denom).sum()

# %%
ys = [ex(n, 0) for n in range(1, 513)]
plt.plot(ys)
plt.xlabel("n")
plt.ylabel("E[X]")
# Out:
# Text(0, 0.5, 'E[X]')
